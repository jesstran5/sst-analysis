# %% [markdown]
# # Cobe Functions Test
# ## Jessica Tran

# %%
import cobe_functions

# Dataset path to read from
dataset_path = 'sst.mon.mean.nc'

# Read the latest dataset in last time value
sst_latest_dataset = cobe_functions.read_latest_sst(dataset_path)
print(f'latest: {sst_latest_dataset}')

# Get both the time series and temperature data at given coordinate (example of 160 latitude and 130 longitude)
time_series, temperatures = cobe_functions.get_time_series_at_coordinate_latest_sst(160, 130, dataset_path)
print(f'time series: {time_series} temperatures: {temperatures}')

# Read entire dataset for all time values
sst_entire_dataset = cobe_functions.read_entire_ds(dataset_path)
print(f'entire dataset: {sst_entire_dataset}')

# Get just the time series for the entire dataset
time_series = cobe_functions.get_times_from_dataset(sst_entire_dataset)
print(f'time series: {time_series}')

# Check labs for more details
# cobe_functions.get_velocity_slope_from_dataset_coordinate()
# Out:
# latest: <xarray.DataArray 'sst' (lat: 180, lon: 360)> Size: 259kB
# array([[-1.7949996, -1.7974995, -1.7974995, ..., -1.7974995, -1.7949996,
#         -1.7974995],
#        [-1.7974995, -1.7899995, -1.7899995, ..., -1.7949996, -1.7924995,
#         -1.7899995],
#        [-1.7974995, -1.7949996, -1.7974995, ..., -1.7924995, -1.7949996,
#         -1.7924995],
#        ...,
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan],
#        [       nan,        nan,        nan, ...,        nan,        nan,
#                nan]], shape=(180, 360), dtype=float32)
# Coordinates:
#   * lat      (lat) float32 720B 89.5 88.5 87.5 86.5 ... -86.5 -87.5 -88.5 -89.5
#   * lon      (lon) float32 1kB 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
#     time     datetime64[ns] 8B 2023-06-01
# Attributes:
# ...
